# %% [markdown]
# # Assignment #03
# 1. Explore College Scorecard website - https://collegescorecard.ed.gov/
#
# 2. Explore College Scorecard Data web page - https://collegescorecard.ed.gov/data/
#
# 3. Download and skim the documentation - https://collegescorecard.ed.gov/assets/FullDataDocumentation.pdf
#
# 4. Download the dataset - https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip (265MB Zip File)
#
# 5. Unzip the file into a folder (there are many files, one for each school year)
#
# 6. Import the 2017-2018 school year file "MERGED2017_18_PP.csv" and explore:
#
#     * how many colleges or rows?
#
#     * how many variables or columns?
#
#     * Look at the first 20 rows
#
#     * look at the last 20 rows
#
#     * Look at a random sample of 20 rows
#
# 7. Since there are too many variables to explore, many of which are not interesting. Modify your import statement to only import the following 9 variables:
#
# - UNITID
# - INSTNM
# - CITY
# - STABBR
# - ZIP
# - ADM_RATE
# - UGDS
# - TUITIONFEE_IN
# - MN_EARN_WNE_P10
#
# 8. Download and read the data dictionary file - https://collegescorecard.ed.gov/assets/CollegeScorecardDataDictionary.xlsx
#
# Find out the definition of the above 9 variables and document the definitions in the Jupyter Notebook so that the readers will not need to repeat what you have done to know the meaning of these variables.
#
# 9. Use the predefined cells below to conduct and document your data exploration.
#
# When in doubt, Google. Find examples and read documents/tutorials.
#
# Have fun!

# %%
# Import libraries
import pandas as pd

# %%
# load the 2017-2018 school year file "MERGED2017_18_PP.csv"  
df = pd.read_csv('MERGED2017_18_PP.csv',skipinitialspace = True, low_memory = False)
df.head(3)
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
#
#   STABBR         ZIP                                       ACCREDAGENCY  \
# 0     AL       35762  Southern Association of Colleges and Schools C...
# 1     AL  35294-0110  Southern Association of Colleges and Schools C...
# 2     AL  36117-3553  Southern Association of Colleges and Schools C...
#
#                      INSTURL  \
# 0              www.aamu.edu/
# 1                www.uab.edu
# 2  www.amridgeuniversity.edu
#
#                                               NPCURL  ...  \
# 0  https://galileo.aamu.edu/NetPriceCalculator/np...  ...
# 1           uab.studentaidcalculator.com/survey.aspx  ...
# 2                   www2.amridgeuniversity.edu:9091/  ...
#
# ...

# %%
# Find out how many colleges or rows?   
# Find out how many variables or columns?
print('The number of rows is:', df.shape[0])
print('The number of columns is:', df.shape[1])
# Out:
# The number of rows is: 7112
# The number of columns is: 1977

# %%
# Look at the first 20 rows  
print(df.head(20))
# Out:
#     UNITID    OPEID  OPEID6                                     INSTNM  \
# 0   100654   100200    1002                   Alabama A & M University
# 1   100663   105200    1052        University of Alabama at Birmingham
# 2   100690  2503400   25034                         Amridge University
# 3   100706   105500    1055        University of Alabama in Huntsville
# 4   100724   100500    1005                   Alabama State University
# 5   100751   105100    1051                  The University of Alabama
# 6   100760   100700    1007          Central Alabama Community College
# 7   100812   100800    1008                    Athens State University
# 8   100830   831000    8310            Auburn University at Montgomery
# 9   100858   100900    1009                          Auburn University
# 10  100937   101200    1012                Birmingham Southern College
# 11  101028  1218200   12182     Chattahoochee Valley Community College
# ...

# %%
# Look at the last 20 rows 
print(df.tail(20))
# Out:
#         UNITID    OPEID  OPEID6  \
# 7092  47503311  4208611   42086
# 7093  47503312  4208612   42086
# 7094  47503313  4208613   42086
# 7095  47647001  4088301   40883
# 7096  47662901  4189101   41891
# 7097  47691101  4205801   42058
# 7098  48065701   869423    8694
# 7099  48079001  4218901   42189
# 7100  48092101  4220001   42200
# 7101  48133101  4213501   42135
# 7102  48154401  4220901   42209
# 7103  48305401  4224601   42246
# 7104  48312401   108131    1081
# 7105  48312402   108161    1081
# 7106  48312403   108162    1081
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM              CITY  \
# 7092   Relay Graduate School of Education - San Antonio       San Antonio
# 7093  Relay Graduate School of Education - Dallas-Fo...            Dallas
# ...

# %%
# Look at a random sample of 20 rows    
print(df.sample(20))
# Out:
#         UNITID    OPEID  OPEID6  \
# 5167    447175  2173207   21732
# 6800  16210401   830801    8308
# 2544    199139   297500    2975
# 4719    431983  2546300   25463
# 6748  13830903   869420    8694
# 1403    160472  2518300   25183
# 2184    188526   288500    2885
# 6789  15628601   195403    1954
# 3911    241182  2234900   22349
# 1307    156745   196400    1964
# 2922    210146   321900    3219
# 301     114415  1111203   11112
# 677     133553   147900    1479
# 5944    474924  1085802   10858
# 6082    480161  4038701   40387
# 6045    476966  4207900   42079
# 4971    442657  3098700   30987
# 147     107071   109800    1098
# 3330    220473   349500    3495
# 5572    456940  2069303   20693
#
#                                                  INSTNM               CITY  \
# 5167                        Empire Beauty School-Aurora             Aurora
# 6800                     Cecil College - Elkton Station             Elkton
# ...

# %% [markdown]
# Read (with naked eyes, not computer) the dictionary and find out the definitions of the following 9 columns and copy the text next to the column name
# - UNITID: The unique identification number assigned to postsecondary institutions as surveyed through IPEDS.
# - INSTNM: The institution’s name
# - CITY: The institution's location   (city)
# - ZIP: The institution's location    (zip code)
# - ADM_RATE: The admissions rate at each campus
# - UGDS: Includes the number of degree/certificate-seeking undergraduates enrolled in the fall, as reported in the IPEDS Fall Enrollment component.
# - TUITIONFEE_IN: The cost data include the tuition and required fees of the institution. They are provided for in-state students
# - MN_EARN_WNE_P10: Mean earnings for the institutional aggregate of all federally aided students who enroll in an institution each year and who are employed but not enrolled. Earnings are defined as the sum of wages and deferred compensation from all non-duplicate W-2 forms received for each individual, plus positive self-employment earnings from Schedule SE.

# %%
# reimport the data with above 9 columns (ignore all other variables)
df = pd.read_csv('MERGED2017_18_PP.csv',skipinitialspace = True, usecols = ['UNITID','INSTNM','CITY','STABBR','ZIP','ADM_RATE','UGDS','TUITIONFEE_IN','MN_EARN_WNE_P10'])

# %%
# Find out the 10 colleges that are hardest to get in (top 10)
mydf = df[df.get('ADM_RATE') != 0]
print(mydf.nsmallest(10,'ADM_RATE'))
# Out:
#       UNITID                                       INSTNM          CITY  \
# 2978  211893                    Curtis Institute of Music  Philadelphia
# 3979  243744                          Stanford University      Stanford
# 1557  166027                           Harvard University     Cambridge
# 2302  192110                         The Juilliard School      New York
# 2123  186131                         Princeton University     Princeton
# 2233  190150  Columbia University in the City of New York      New York
# 633   130794                              Yale University     New Haven
# 1575  166683        Massachusetts Institute of Technology     Cambridge
# 212   110404           California Institute of Technology      Pasadena
# 427   121345                               Pomona College     Claremont
#
#      STABBR         ZIP  ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 2978     PA       19103    0.0330   131.0         2675.0              NaN
# ...

# %%
# 10. Find out the average in-state tuition of top 10
mycol = df.get('TUITIONFEE_IN')
my10 = mycol.nlargest(10)
print("Average in state tuition for the top 10 reporting schools: $", my10.mean())
# Out:
# Average in state tuition for the top 10 reporting schools: $ 57050.4

# %%
# Find out the average earnings of graduates from the top 10
df5 = df.nlargest(10,'ADM_RATE')
mycol3 = df5.get('MN_EARN_WNE_P10')
print("The average earnings of graduates from the bottom 10 schools is: $", mycol3.mean(),"because data is listed as NULL for the 2017-2018 year")
# Out:
# The average earnings of graduates from the bottom 10 schools is: $ nan because data is listed as NULL for the 2017-2018 year

# %%
# Find out the 10 colleges that are easiest to get in (bottom 10)
print(df.nlargest(10,'ADM_RATE'))
# Out:
#       UNITID                                      INSTNM        CITY STABBR  \
# 24    101453               Heritage Christian University    Florence     AL
# 240   110918                California Christian College      Fresno     CA
# 370   118161    Lytles Redwood Empire Beauty College Inc  Santa Rosa     CA
# 472   123280    Shasta Bible College and Graduate School     Redding     CA
# 559   127653                           Naropa University     Boulder     CO
# 571   127954  Montessori Education Center of the Rockies     Boulder     CO
# 652   131830      National Conservatory of Dramatic Arts  Washington     DC
# 665   132842              Carlos Albizu University-Miami       Miami     FL
# 887   142090                         Boise Bible College       Boise     ID
# 1011  147165                            Midstate College      Peoria     IL
#
#              ZIP  ADM_RATE   UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 24    35630-9977       1.0   59.0        11232.0              NaN
# ...

# %%
# Find out the average in-state tuition of the bottom 10
df3 = df.nlargest(10,'ADM_RATE')
mycol1 = df3.get('TUITIONFEE_IN')
print("The average in state tuition for the bottom 10 schools is: $", mycol1.mean() )
# Out:
# The average in state tuition for the bottom 10 schools is: $ 14383.25

# %%
# Find out the average earnings of graduates from the bottom 10
df4 = df.nsmallest(10,'ADM_RATE')
mycol2 = df4.get('MN_EARN_WNE_P10')
print("The average earnings of graduates from the bottom 10 schools is: $", mycol2.mean(),"because data is listed as NULL for the 2017-2018 year")
# Out:
# The average earnings of graduates from the bottom 10 schools is: $ nan because data is listed as NULL for the 2017-2018 year
